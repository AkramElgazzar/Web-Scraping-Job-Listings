# %% [markdown]
# ##### """
#
# This script utilizes BeautifulSoup and pandas to scrape job information from Wuzzuf.net.
#
# It fetches details such as:
#
# * Job Name
# * Company
# * Location
# * Job Type
# * Experience Level
# * Skills
#
# The data is stored in a pandas DataFrame for further analysis.
#
# """

# %% [markdown]
# ####  Import necessary libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings

# Ignore all warnings for this cell
warnings.filterwarnings('ignore')

# %% [markdown]
# #### DataFrame Initialization

# %%
# Define column names for job information
job_columns = [
    "job_name",
    "company_name",
    "location",
    "job_type",
    "experience_level",
    "years_experience",
    "skills"
]

# Create an empty DataFrame to store the extracted job data
df = pd.DataFrame(columns=job_columns)

# %% [markdown]
# #### Web Scraping

# %%
# Iterate through each page of job listings
for page_index in range(644):
    
    # Make a request to the job search website
    url = f"https://wuzzuf.net/search/jobs/?a=hpb&q=&start={page_index}"
    
     # Fetch and Parse the HTML content of the page
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content, "html.parser")

    # Extract job information from each job listing
    job_listings = soup.find_all("div", class_="css-1gatmva e1v1l3u10")

    # Process each job listing
    for job in job_listings:
        
        # Extract job details
        job_name = job.find_all("h2", class_="css-m604qf")[0].text
        company_name = job.find_all("div", class_="css-d7j1kk")[0].text.split(" - ")[0]
        location = job.find_all("span", class_="css-5wys0k")[0].text
        job_type = job.find_all("span", class_="css-1ve4b75 eoyjyou0")[0].text
        experience_level = job.find_all("div", class_="css-1lh32fc")[0].next_sibling.text.split(" · ")[0]
        years_experience = job.find_all("div", class_="css-1lh32fc")[0].next_sibling.text.split(" · ")[1]
        skills = " ".join(job.find_all("div", class_="css-1lh32fc")[0].next_sibling.text.split(" · ")[2:])
        
        
        # Append job details to the DataFrame
        df.loc[len(df.index)] = [
            job_name,
            company_name,
            location,
            job_type,
            experience_level,
            years_experience,
            skills
        ]
        
       
    # Print progress every 30 iterations
    if page_index % 30 == 0:
        print("Scraping in progress...")


    if page_index == 643: 
        print("Scraping finished!")
# Out:
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping in progress...
# Scraping finished!

# %% [markdown]
# #### Display the final DataFrame

# %%
df
# Out:
#                                                 job_name  \
# 0                                Senior Graphic Designer
# 1             Head section of Accounts Contracting Field
# 2                          Social Media Graphic Designer
# 3      Title: Dynamic Social Media Specialist & Websi...
# 4                                   Business Development
# ...                                                  ...
# 17740                          Technical Office Engineer
# 17741                    Civil Technical Office Engineer
# 17742                               Planning Coordinator
# 17743                                   Teller - Red Sea
# 17744                   Junior Accountant (Sokhna Plant)
#
#                       company_name                      location   job_type  \
# 0               Max2 Digital Media     Heliopolis, Cairo, Egypt   Full Time
# 1                       Giza power           Dokki, Giza, Egypt   Full Time
# 2                     Naief Design                 Muscat, Oman   Full Time
# 3                  Mediumward Inc.              Toronto, Canada   Full Time
# 4                     Confidential          Maadi, Cairo, Egypt   Full Time
# ...                            ...                           ...        ...
# 17740  TMA For Industrial Supplies      Nasr City, Cairo, Egypt   Full Time
# 17741                Kandeel Group      New Cairo, Cairo, Egypt   Full Time
# 17742              Power Solutions  6th of October, Giza, Egypt   Full Time
# 17743                 Confidential     Hurghada, Red Sea, Egypt   Full Time
# 17744              FlexFilms Egypt  6th of October, Giza, Egypt   Full Time
#
#       experience_level    years_experience  \
# 0          Experienced   6 - 10 Yrs of Exp
# 1          Experienced  10 - 15 Yrs of Exp
# 2          Entry Level    3 - 5 Yrs of Exp
# 3          Experienced    3 - 7 Yrs of Exp
# 4              Manager   7 - 10 Yrs of Exp
# ...                ...                 ...
# 17740      Experienced    3 - 7 Yrs of Exp
# 17741      Experienced    3 - 6 Yrs of Exp
# 17742      Experienced    2 - 3 Yrs of Exp
# 17743      Entry Level    0 - 2 Yrs of Exp
# 17744      Entry Level    1 - 2 Yrs of Exp
#
#                                                   skills
# 0      Creative/Design/Art Adobe Photoshop English De...
# 1      Accounting/Finance Operations/Management Accou...
# 2      Creative/Design/Art social media designer grap...
# 3      Marketing/PR/Advertising Social media design M...
# 4      Business Development Sales/Retail Engineering ...
# ...                                                  ...
# 17740  Engineering - Construction/Civil/Architecture ...
# 17741  Engineering - Construction/Civil/Architecture ...
# 17742  females_only Logistics/Supply Chain Engineerin...
# 17743  Accounting/Finance Customer Service/Support Cu...
# 17744  males_only Accounting/Finance Banking Accounti...
#
# [17745 rows x 7 columns]
